# %%
# part 1
import itertools


def get_param(a, input_index, param_mode):
    if param_mode == 1:
        return input_index
    else:
        return a[input_index] if input_index < len(a) else 0


def get_digit(number, n):
    return number // 10**n % 10


def get_params(a, input_index):
    param_1_mode, param_2_mode, param_3_mode = [
        get_digit(a[input_index], i) for i in range(2, 5)
    ]
    param_1 = get_param(a, input_index + 1, param_1_mode)
    param_2 = get_param(a, input_index + 2, param_2_mode)
    param_3 = get_param(a, input_index + 3, param_3_mode)
    return param_1, param_2, param_3


def opcode_1(input_index, a, param_1, param_2, param_3):
    a[param_3] = a[param_1] + a[param_2]
    input_index += 4
    return a, input_index


def opcode_2(input_index, a, param_1, param_2, param_3):
    a[param_3] = a[param_1] * a[param_2]
    input_index += 4
    return a, input_index


def opcode_3(input_index, a, param_1, param_2):
    a[param_1] = param_2
    input_index += 2
    return a, input_index


def opcode_4(input_index, a, param_1):
    input_index += 2
    return a, input_index, a[param_1]


def opcode_5(input_index, a, param_1, param_2):
    if a[param_1] > 0:
        input_index = a[param_2]
    else:
        input_index += 3
    return a, input_index


def opcode_6(input_index, a, param_1, param_2):
    if a[param_1] == 0:
        input_index = a[param_2]
    else:
        input_index += 3
    return a, input_index


def opcode_7(input_index, a, param_1, param_2, param_3):
    if a[param_1] < a[param_2]:
        a[param_3] = 1
    else:
        a[param_3] = 0
    input_index += 4
    return a, input_index


def opcode_8(input_index, a, param_1, param_2, param_3):
    if a[param_1] == a[param_2]:
        a[param_3] = 1
    else:
        a[param_3] = 0
    input_index += 4
    return a, input_index


def intcode(a, a_input):
    input_index = 0
    while a[input_index] != 99:
        opcode = a[input_index] % 100
        param_1, param_2, param_3 = get_params(a, input_index)

        if opcode == 1:
            a, input_index = opcode_1(input_index, a, param_1, param_2,
                                      param_3)
        elif opcode == 2:
            a, input_index = opcode_2(input_index, a, param_1, param_2,
                                      param_3)
        elif opcode == 3:
            param_2 = a_input.pop(0)
            a, input_index = opcode_3(input_index, a, param_1, param_2)
        elif opcode == 4:
            a, input_index, out_result = opcode_4(input_index, a, param_1)
            yield out_result
        elif opcode == 5:
            a, input_index = opcode_5(input_index, a, param_1, param_2)
        elif opcode == 6:
            a, input_index = opcode_6(input_index, a, param_1, param_2)
        elif opcode == 7:
            a, input_index = opcode_7(input_index, a, param_1, param_2,
                                      param_3)
        elif opcode == 8:
            a, input_index = opcode_8(input_index, a, param_1, param_2,
                                      param_3)
        else:
            print("wrong opcode " + str(input_index))
            break
    yield None


code = [
    3, 8, 1001, 8, 10, 8, 105, 1, 0, 0, 21, 46, 67, 88, 101, 126, 207, 288,
    369, 450, 99999, 3, 9, 1001, 9, 5, 9, 1002, 9, 5, 9, 1001, 9, 5, 9, 102, 3,
    9, 9, 101, 2, 9, 9, 4, 9, 99, 3, 9, 102, 4, 9, 9, 101, 5, 9, 9, 102, 5, 9,
    9, 101, 3, 9, 9, 4, 9, 99, 3, 9, 1001, 9, 3, 9, 102, 2, 9, 9, 1001, 9, 5,
    9, 102, 4, 9, 9, 4, 9, 99, 3, 9, 102, 3, 9, 9, 1001, 9, 4, 9, 4, 9, 99, 3,
    9, 102, 3, 9, 9, 1001, 9, 3, 9, 1002, 9, 2, 9, 101, 4, 9, 9, 102, 3, 9, 9,
    4, 9, 99, 3, 9, 101, 2, 9, 9, 4, 9, 3, 9, 101, 2, 9, 9, 4, 9, 3, 9, 101, 2,
    9, 9, 4, 9, 3, 9, 102, 2, 9, 9, 4, 9, 3, 9, 1001, 9, 1, 9, 4, 9, 3, 9,
    1002, 9, 2, 9, 4, 9, 3, 9, 102, 2, 9, 9, 4, 9, 3, 9, 101, 2, 9, 9, 4, 9, 3,
    9, 102, 2, 9, 9, 4, 9, 3, 9, 101, 1, 9, 9, 4, 9, 99, 3, 9, 101, 1, 9, 9, 4,
    9, 3, 9, 1001, 9, 2, 9, 4, 9, 3, 9, 1001, 9, 2, 9, 4, 9, 3, 9, 102, 2, 9,
    9, 4, 9, 3, 9, 1001, 9, 2, 9, 4, 9, 3, 9, 102, 2, 9, 9, 4, 9, 3, 9, 102, 2,
    9, 9, 4, 9, 3, 9, 1001, 9, 1, 9, 4, 9, 3, 9, 1001, 9, 1, 9, 4, 9, 3, 9,
    1002, 9, 2, 9, 4, 9, 99, 3, 9, 101, 1, 9, 9, 4, 9, 3, 9, 1001, 9, 1, 9, 4,
    9, 3, 9, 102, 2, 9, 9, 4, 9, 3, 9, 102, 2, 9, 9, 4, 9, 3, 9, 1001, 9, 1, 9,
    4, 9, 3, 9, 1001, 9, 1, 9, 4, 9, 3, 9, 1001, 9, 2, 9, 4, 9, 3, 9, 101, 2,
    9, 9, 4, 9, 3, 9, 101, 2, 9, 9, 4, 9, 3, 9, 1001, 9, 1, 9, 4, 9, 99, 3, 9,
    101, 2, 9, 9, 4, 9, 3, 9, 101, 2, 9, 9, 4, 9, 3, 9, 1002, 9, 2, 9, 4, 9, 3,
    9, 101, 2, 9, 9, 4, 9, 3, 9, 1001, 9, 1, 9, 4, 9, 3, 9, 101, 2, 9, 9, 4, 9,
    3, 9, 1002, 9, 2, 9, 4, 9, 3, 9, 101, 1, 9, 9, 4, 9, 3, 9, 101, 1, 9, 9, 4,
    9, 3, 9, 101, 1, 9, 9, 4, 9, 99, 3, 9, 101, 1, 9, 9, 4, 9, 3, 9, 102, 2, 9,
    9, 4, 9, 3, 9, 1002, 9, 2, 9, 4, 9, 3, 9, 101, 1, 9, 9, 4, 9, 3, 9, 1002,
    9, 2, 9, 4, 9, 3, 9, 1002, 9, 2, 9, 4, 9, 3, 9, 1001, 9, 2, 9, 4, 9, 3, 9,
    1002, 9, 2, 9, 4, 9, 3, 9, 1001, 9, 2, 9, 4, 9, 3, 9, 102, 2, 9, 9, 4, 9,
    99
]
test = [
    3, 31, 3, 32, 1002, 32, 10, 32, 1001, 31, -2, 31, 1007, 31, 0, 33, 1002,
    33, 7, 33, 1, 33, 31, 31, 1, 32, 31, 31, 4, 31, 99, 0, 0, 0
]

phases = list(itertools.permutations([0, 1, 2, 3, 4]))


def run_amplifiers(a, phases):
    max_thrust = (0, [])
    for phase in phases:
        inp = 0
        for p in phase:
            inp = next(intcode(a, [p, inp]))
        if max_thrust[0] < inp:
            max_thrust = (inp, phase)
    return max_thrust


print(run_amplifiers(test, phases))
print(run_amplifiers(code, phases))
# Out:
# (65210, (1, 0, 4, 3, 2))
# (844468, (0, 2, 3, 4, 1))

# %%
# part 2


def get_param(a, input_index, param_mode):
    if param_mode == 1:
        return input_index
    else:
        return a[input_index] if input_index < len(a) else 0


def get_digit(number, n):
    return number // 10**n % 10


def get_params(a, input_index):
    param_1_mode, param_2_mode, param_3_mode = [
        get_digit(a[input_index], i) for i in range(2, 5)
    ]
    param_1 = get_param(a, input_index + 1, param_1_mode)
    param_2 = get_param(a, input_index + 2, param_2_mode)
    param_3 = get_param(a, input_index + 3, param_3_mode)
    return param_1, param_2, param_3


def opcode_1(input_index, a, param_1, param_2, param_3):
    a[param_3] = a[param_1] + a[param_2]
    input_index += 4
    return a, input_index


def opcode_2(input_index, a, param_1, param_2, param_3):
    a[param_3] = a[param_1] * a[param_2]
    input_index += 4
    return a, input_index


def opcode_3(input_index, a, param_1, param_2):
    a[param_1] = param_2
    input_index += 2
    return a, input_index


def opcode_4(input_index, a, param_1):
    input_index += 2
    return a, input_index, a[param_1]


def opcode_5(input_index, a, param_1, param_2):
    if a[param_1] > 0:
        input_index = a[param_2]
    else:
        input_index += 3
    return a, input_index


def opcode_6(input_index, a, param_1, param_2):
    if a[param_1] == 0:
        input_index = a[param_2]
    else:
        input_index += 3
    return a, input_index


def opcode_7(input_index, a, param_1, param_2, param_3):
    if a[param_1] < a[param_2]:
        a[param_3] = 1
    else:
        a[param_3] = 0
    input_index += 4
    return a, input_index


def opcode_8(input_index, a, param_1, param_2, param_3):
    if a[param_1] == a[param_2]:
        a[param_3] = 1
    else:
        a[param_3] = 0
    input_index += 4
    return a, input_index


def intcode(a, a_input):
    input_index = 0
    while a[input_index] != 99:
        opcode = a[input_index] % 100
        param_1, param_2, param_3 = get_params(a, input_index)

        if opcode == 1:
            a, input_index = opcode_1(input_index, a, param_1, param_2,
                                      param_3)
        elif opcode == 2:
            a, input_index = opcode_2(input_index, a, param_1, param_2,
                                      param_3)
        elif opcode == 3:
            param_2 = a_input.pop(0)
            a, input_index = opcode_3(input_index, a, param_1, param_2)
        elif opcode == 4:
            a, input_index, out_result = opcode_4(input_index, a, param_1)
            yield out_result
        elif opcode == 5:
            a, input_index = opcode_5(input_index, a, param_1, param_2)
        elif opcode == 6:
            a, input_index = opcode_6(input_index, a, param_1, param_2)
        elif opcode == 7:
            a, input_index = opcode_7(input_index, a, param_1, param_2,
                                      param_3)
        elif opcode == 8:
            a, input_index = opcode_8(input_index, a, param_1, param_2,
                                      param_3)
        else:
            print("wrong opcode " + str(input_index))
            break
    yield None


code = [
    3, 8, 1001, 8, 10, 8, 105, 1, 0, 0, 21, 46, 67, 88, 101, 126, 207, 288,
    369, 450, 99999, 3, 9, 1001, 9, 5, 9, 1002, 9, 5, 9, 1001, 9, 5, 9, 102, 3,
    9, 9, 101, 2, 9, 9, 4, 9, 99, 3, 9, 102, 4, 9, 9, 101, 5, 9, 9, 102, 5, 9,
    9, 101, 3, 9, 9, 4, 9, 99, 3, 9, 1001, 9, 3, 9, 102, 2, 9, 9, 1001, 9, 5,
    9, 102, 4, 9, 9, 4, 9, 99, 3, 9, 102, 3, 9, 9, 1001, 9, 4, 9, 4, 9, 99, 3,
    9, 102, 3, 9, 9, 1001, 9, 3, 9, 1002, 9, 2, 9, 101, 4, 9, 9, 102, 3, 9, 9,
    4, 9, 99, 3, 9, 101, 2, 9, 9, 4, 9, 3, 9, 101, 2, 9, 9, 4, 9, 3, 9, 101, 2,
    9, 9, 4, 9, 3, 9, 102, 2, 9, 9, 4, 9, 3, 9, 1001, 9, 1, 9, 4, 9, 3, 9,
    1002, 9, 2, 9, 4, 9, 3, 9, 102, 2, 9, 9, 4, 9, 3, 9, 101, 2, 9, 9, 4, 9, 3,
    9, 102, 2, 9, 9, 4, 9, 3, 9, 101, 1, 9, 9, 4, 9, 99, 3, 9, 101, 1, 9, 9, 4,
    9, 3, 9, 1001, 9, 2, 9, 4, 9, 3, 9, 1001, 9, 2, 9, 4, 9, 3, 9, 102, 2, 9,
    9, 4, 9, 3, 9, 1001, 9, 2, 9, 4, 9, 3, 9, 102, 2, 9, 9, 4, 9, 3, 9, 102, 2,
    9, 9, 4, 9, 3, 9, 1001, 9, 1, 9, 4, 9, 3, 9, 1001, 9, 1, 9, 4, 9, 3, 9,
    1002, 9, 2, 9, 4, 9, 99, 3, 9, 101, 1, 9, 9, 4, 9, 3, 9, 1001, 9, 1, 9, 4,
    9, 3, 9, 102, 2, 9, 9, 4, 9, 3, 9, 102, 2, 9, 9, 4, 9, 3, 9, 1001, 9, 1, 9,
    4, 9, 3, 9, 1001, 9, 1, 9, 4, 9, 3, 9, 1001, 9, 2, 9, 4, 9, 3, 9, 101, 2,
    9, 9, 4, 9, 3, 9, 101, 2, 9, 9, 4, 9, 3, 9, 1001, 9, 1, 9, 4, 9, 99, 3, 9,
    101, 2, 9, 9, 4, 9, 3, 9, 101, 2, 9, 9, 4, 9, 3, 9, 1002, 9, 2, 9, 4, 9, 3,
    9, 101, 2, 9, 9, 4, 9, 3, 9, 1001, 9, 1, 9, 4, 9, 3, 9, 101, 2, 9, 9, 4, 9,
    3, 9, 1002, 9, 2, 9, 4, 9, 3, 9, 101, 1, 9, 9, 4, 9, 3, 9, 101, 1, 9, 9, 4,
    9, 3, 9, 101, 1, 9, 9, 4, 9, 99, 3, 9, 101, 1, 9, 9, 4, 9, 3, 9, 102, 2, 9,
    9, 4, 9, 3, 9, 1002, 9, 2, 9, 4, 9, 3, 9, 101, 1, 9, 9, 4, 9, 3, 9, 1002,
    9, 2, 9, 4, 9, 3, 9, 1002, 9, 2, 9, 4, 9, 3, 9, 1001, 9, 2, 9, 4, 9, 3, 9,
    1002, 9, 2, 9, 4, 9, 3, 9, 1001, 9, 2, 9, 4, 9, 3, 9, 102, 2, 9, 9, 4, 9,
    99
]
test = [
    3, 26, 1001, 26, -4, 26, 3, 27, 1002, 27, 2, 27, 1, 27, 26, 27, 4, 27,
    1001, 28, -1, 28, 1005, 28, 6, 99, 0, 0, 5
]
test2 = [
    3, 52, 1001, 52, -5, 52, 3, 53, 1, 52, 56, 54, 1007, 54, 5, 55, 1005, 55,
    26, 1001, 54, -5, 54, 1105, 1, 12, 1, 53, 54, 53, 1008, 54, 0, 55, 1001,
    55, 1, 55, 2, 53, 55, 53, 4, 53, 1001, 56, -1, 56, 1005, 56, 6, 99, 0, 0,
    0, 0, 10
]


def setup_amplifiers_connections(program, phase):
    inputs = [[p] for p in phase]
    inputs[0].append(0)
    amps = {
        i: {
            'code_runner': intcode(program[:], inputs[i]),
            'next_input': inputs[i + 1],
            'next_amp_index': i + 1,
            'index': i
        }
        for i in range(4)
    }
    amps[4] = {
        'code_runner': intcode(program[:], inputs[4]),
        'next_input': inputs[0],
        'next_amp_index': 0,
        'index': 4
    }
    return amps


def run_amplifiers_feedback_loop(program, phase):
    amps = setup_amplifiers_connections(program, phase)
    amp_outputs = {}

    active_amp = amps[0]
    while True:
        out = next(active_amp['code_runner'])
        if out is None:
            break
        else:
            active_amp['next_input'].append(out)
            amp_outputs[active_amp['index']] = out
        active_amp = amps[active_amp['next_amp_index']]

    return amp_outputs


def find_max(program):
    max_thrust = (0, phases[0])

    for permutation in list(itertools.permutations([5, 6, 7, 8, 9])):
        result = run_amplifiers_feedback_loop(program[:], permutation)
        if max_thrust[0] < result.get(4):
            max_thrust = (result.get(4), permutation)

    return max_thrust


print(find_max(test))
print(find_max(test2))
print(find_max(code))
# Out:
# (139629729, (9, 8, 7, 6, 5))
# (18216, (9, 7, 8, 5, 6))
# (4215746, (6, 5, 8, 7, 9))
